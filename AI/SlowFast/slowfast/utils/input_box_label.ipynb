# %%
import cv2
from matplotlib import pyplot as plt

# %%
image = cv2.imread('/Users/woo/Desktop/woo/project/AbnormalBehaviorDetection_System/AI/SlowFast/datasets/train/002/00000171.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)
plt.show()

# %%
x1, y1, x2, y2 = 1300, 1200, 2000, 2000

# %%
src = cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 10)

# %%
plt.imshow(src)
plt.show()

# %%
src1 = cv2.putText(src, 'assualt', (x1, y1 - 30), 0, 4, (255, 0, 0), 10, cv2.LINE_AA, bottomLeftOrigin = False)

# %%
plt.imshow(src1)
plt.show()
